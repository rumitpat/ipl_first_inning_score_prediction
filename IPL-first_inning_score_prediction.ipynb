# %%
# Importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
# Loading the dataset
data =pd.read_csv("ipl.csv")
data.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
data.tail()
# Out:
#        mid        date                                      venue  \
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#              bat_team               bowl_team     batsman        bowler  runs  \
# 76009  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   121
# 76010  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   127
# 76011  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   128
# 76012  Mumbai Indians  Rising Pune Supergiant  MG Johnson  DT Christian   129
# 76013  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   129
#
#        wickets  overs  runs_last_5  wickets_last_5  striker  non-striker  \
# ...

# %%
data.shape
# Out:
# (76014, 15)

# %%
data.isnull().sum( )
# Out:
# mid               0
# date              0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
data.dtypes
# Out:
# mid                 int64
# date               object
# venue              object
# bat_team           object
# bowl_team          object
# batsman            object
# bowler             object
# runs                int64
# wickets             int64
# overs             float64
# runs_last_5         int64
# wickets_last_5      int64
# striker             int64
# non-striker         int64
# total               int64
# dtype: object

# %%
# --- Data Cleaning ---
data["bat_team"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
# Keeping only consistent teams
consistent_teams =['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
       'Mumbai Indians','Kings XI Punjab',
       'Royal Challengers Bangalore', 'Delhi Daredevils','Sunrisers Hyderabad']

# %%
data =data[(data["bat_team"].isin(consistent_teams)) & (data["bowl_team"].isin(consistent_teams))]

# %%
data.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
data.shape
# Out:
# (53811, 15)

# %%
data.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
# Removing unwanted columns
columns_to_remove =["mid","batsman","bowler","striker","non-striker"]

# %%
data.drop(labels =columns_to_remove ,axis=1,inplace =True)

# %%
data.head()
# Out:
#          date                  venue               bat_team  \
# 0  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team  runs  wickets  overs  runs_last_5  \
# 0  Royal Challengers Bangalore     1        0    0.1            1
# 1  Royal Challengers Bangalore     1        0    0.2            1
# 2  Royal Challengers Bangalore     2        0    0.2            2
# 3  Royal Challengers Bangalore     2        0    0.3            2
# 4  Royal Challengers Bangalore     2        0    0.4            2
#
#    wickets_last_5  total
# 0               0    222
# 1               0    222
# 2               0    222
# 3               0    222
# 4               0    222

# %%
# removing first five over data from every matches
data =data[data["overs"]>5.0]

# %%
data["year"] =data["date"].str.split("-").str[0]

# %%
data.head()
# Out:
#           date                  venue               bat_team  \
# 32  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 33  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 34  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 35  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 36  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                       bowl_team  runs  wickets  overs  runs_last_5  \
# 32  Royal Challengers Bangalore    61        0    5.1           59
# 33  Royal Challengers Bangalore    61        1    5.2           59
# 34  Royal Challengers Bangalore    61        1    5.3           59
# 35  Royal Challengers Bangalore    61        1    5.4           59
# 36  Royal Challengers Bangalore    61        1    5.5           58
#
#     wickets_last_5  total  year
# 32               0    222  2008
# 33               1    222  2008
# 34               1    222  2008
# 35               1    222  2008
# ...

# %%
data =data.drop(["date"],axis =1)

# %%
data.head()
# Out:
#                     venue               bat_team                    bowl_team  \
# 32  M Chinnaswamy Stadium  Kolkata Knight Riders  Royal Challengers Bangalore
# 33  M Chinnaswamy Stadium  Kolkata Knight Riders  Royal Challengers Bangalore
# 34  M Chinnaswamy Stadium  Kolkata Knight Riders  Royal Challengers Bangalore
# 35  M Chinnaswamy Stadium  Kolkata Knight Riders  Royal Challengers Bangalore
# 36  M Chinnaswamy Stadium  Kolkata Knight Riders  Royal Challengers Bangalore
#
#     runs  wickets  overs  runs_last_5  wickets_last_5  total  year
# 32    61        0    5.1           59               0    222  2008
# 33    61        1    5.2           59               1    222  2008
# 34    61        1    5.3           59               1    222  2008
# 35    61        1    5.4           59               1    222  2008
# 36    61        1    5.5           58               1    222  2008

# %%
#converting categorical feature in to the one hot encoding
data =pd.get_dummies(data, columns=["bat_team"],drop_first =True)
data =pd.get_dummies(data, columns=["bowl_team"],drop_first =True)

# %%
data.head()
# Out:
#                     venue  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 32  M Chinnaswamy Stadium    61        0    5.1           59               0
# 33  M Chinnaswamy Stadium    61        1    5.2           59               1
# 34  M Chinnaswamy Stadium    61        1    5.3           59               1
# 35  M Chinnaswamy Stadium    61        1    5.4           59               1
# 36  M Chinnaswamy Stadium    61        1    5.5           58               1
#
#     total  year  bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32    222  2008                          0                         0
# 33    222  2008                          0                         0
# 34    222  2008                          0                         0
# 35    222  2008                          0                         0
# 36    222  2008                          0                         0
#
#     bat_team_Kolkata Knight Riders  bat_team_Mumbai Indians  \
# ...

# %%
len(data["venue"].unique())
# Out:
# 31

# %%
data["venue"].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Sawai Mansingh Stadium',
#        'MA Chidambaram Stadium, Chepauk', 'Eden Gardens',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera',
#        'Himachal Pradesh Cricket Association Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
#        'Sharjah Cricket Stadium', 'Dubai International Cricket Stadium',
#        'Barabati Stadium', 'Maharashtra Cricket Association Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
# ...

# %%
#one hot encoding using multipal categorics

# %%
data =pd.get_dummies(data, columns=["venue"],drop_first =True)

# %%
data.head()
# Out:
#     runs  wickets  overs  runs_last_5  wickets_last_5  total  year  \
# 32    61        0    5.1           59               0    222  2008
# 33    61        1    5.2           59               1    222  2008
# 34    61        1    5.3           59               1    222  2008
# 35    61        1    5.4           59               1    222  2008
# 36    61        1    5.5           58               1    222  2008
#
#     bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32                          0                         0
# 33                          0                         0
# 34                          0                         0
# 35                          0                         0
# 36                          0                         0
#
#     bat_team_Kolkata Knight Riders  bat_team_Mumbai Indians  \
# 32                               1                        0
# 33                               1                        0
# ...

# %%
data.shape
# Out:
# (40088, 51)

# %%
data.columns
# Out:
# Index(['runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'total',
#        'year', 'bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
#        'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians',
#        'bat_team_Rajasthan Royals', 'bat_team_Royal Challengers Bangalore',
#        'bat_team_Sunrisers Hyderabad', 'bowl_team_Delhi Daredevils',
#        'bowl_team_Kings XI Punjab', 'bowl_team_Kolkata Knight Riders',
#        'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
#        'bowl_team_Royal Challengers Bangalore',
#        'bowl_team_Sunrisers Hyderabad', 'venue_Brabourne Stadium',
#        'venue_Buffalo Park', 'venue_De Beers Diamond Oval',
#        'venue_Dr DY Patil Sports Academy',
#        'venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'venue_Dubai International Cricket Stadium', 'venue_Eden Gardens',
#        'venue_Feroz Shah Kotla',
#        'venue_Himachal Pradesh Cricket Association Stadium',
# ...

# %%
data =data[["year",'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5','bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
       'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians',
       'bat_team_Rajasthan Royals', 'bat_team_Royal Challengers Bangalore',
       'bat_team_Sunrisers Hyderabad', 'bowl_team_Delhi Daredevils',
       'bowl_team_Kings XI Punjab', 'bowl_team_Kolkata Knight Riders',
       'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
       'bowl_team_Royal Challengers Bangalore',
       'bowl_team_Sunrisers Hyderabad', 'venue_Brabourne Stadium',
       'venue_Buffalo Park', 'venue_De Beers Diamond Oval',
       'venue_Dr DY Patil Sports Academy',
       'venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
       'venue_Dubai International Cricket Stadium', 'venue_Eden Gardens',
       'venue_Feroz Shah Kotla','venue_Himachal Pradesh Cricket Association Stadium',
       'venue_Holkar Cricket Stadium',
       'venue_JSCA International Stadium Complex', 'venue_Kingsmead',
       'venue_M Chinnaswamy Stadium', 'venue_MA Chidambaram Stadium, Chepauk',
       'venue_Maharashtra Cricket Association Stadium',
       'venue_New Wanderers Stadium', 'venue_Newlands',
       'venue_OUTsurance Oval',
       'venue_Punjab Cricket Association IS Bindra Stadium, Mohali',
       'venue_Punjab Cricket Association Stadium, Mohali',
       'venue_Rajiv Gandhi International Stadium, Uppal',
       'venue_Sardar Patel Stadium, Motera', 'venue_Sawai Mansingh Stadium',
       'venue_Shaheed Veer Narayan Singh International Stadium',
       'venue_Sharjah Cricket Stadium', 'venue_Sheikh Zayed Stadium',
       "venue_St George's Park", 'venue_Subrata Roy Sahara Stadium',
       'venue_SuperSport Park',"venue_Wankhede Stadium",'total']]

# %%
data.shape
# Out:
# (40088, 51)

# %%
data.head()
# Out:
#     year  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 32  2008    61        0    5.1           59               0
# 33  2008    61        1    5.2           59               1
# 34  2008    61        1    5.3           59               1
# 35  2008    61        1    5.4           59               1
# 36  2008    61        1    5.5           58               1
#
#     bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32                          0                         0
# 33                          0                         0
# 34                          0                         0
# 35                          0                         0
# 36                          0                         0
#
#     bat_team_Kolkata Knight Riders  bat_team_Mumbai Indians  \
# 32                               1                        0
# 33                               1                        0
# 34                               1                        0
# ...

# %%
data.dtypes
# Out:
# year                                                           object
# runs                                                            int64
# wickets                                                         int64
# overs                                                         float64
# runs_last_5                                                     int64
# wickets_last_5                                                  int64
# bat_team_Delhi Daredevils                                       uint8
# bat_team_Kings XI Punjab                                        uint8
# bat_team_Kolkata Knight Riders                                  uint8
# bat_team_Mumbai Indians                                         uint8
# bat_team_Rajasthan Royals                                       uint8
# bat_team_Royal Challengers Bangalore                            uint8
# bat_team_Sunrisers Hyderabad                                    uint8
# ...

# %%
data["year"] =data["year"].astype(int)

# %%
data.dtypes
# Out:
# year                                                            int32
# runs                                                            int64
# wickets                                                         int64
# overs                                                         float64
# runs_last_5                                                     int64
# wickets_last_5                                                  int64
# bat_team_Delhi Daredevils                                       uint8
# bat_team_Kings XI Punjab                                        uint8
# bat_team_Kolkata Knight Riders                                  uint8
# bat_team_Mumbai Indians                                         uint8
# bat_team_Rajasthan Royals                                       uint8
# bat_team_Royal Challengers Bangalore                            uint8
# bat_team_Sunrisers Hyderabad                                    uint8
# ...

# %%
# train and test split
real_x =data.iloc[:,0:50]
real_y =data.iloc[:,50]

# %%
train_x =real_x[real_x["year"]<=2016]
test_x  =real_x[real_x["year"]>2016]
test_x
# Out:
#        year  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 68894  2017    46        1    5.1           42               1
# 68895  2017    50        1    5.2           46               1
# 68896  2017    50        1    5.3           44               1
# 68897  2017    54        1    5.4           48               1
# 68898  2017    58        1    5.5           51               1
# ...     ...   ...      ...    ...          ...             ...
# 75884  2017   106        9   18.1           29               4
# 75885  2017   107        9   18.2           29               4
# 75886  2017   107        9   18.3           28               4
# 75887  2017   107        9   18.4           24               4
# 75888  2017   107       10   18.5           23               5
#
#        bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 68894                          0                         0
# 68895                          0                         0
# ...

# %%
train_y =real_y.iloc[0:37310]
test_y =real_y.iloc[37310:]

# %%
data =data.drop("year" ,axis =1)

# %%
data.head()
# Out:
#     runs  wickets  overs  runs_last_5  wickets_last_5  \
# 32    61        0    5.1           59               0
# 33    61        1    5.2           59               1
# 34    61        1    5.3           59               1
# 35    61        1    5.4           59               1
# 36    61        1    5.5           58               1
#
#     bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32                          0                         0
# 33                          0                         0
# 34                          0                         0
# 35                          0                         0
# 36                          0                         0
#
#     bat_team_Kolkata Knight Riders  bat_team_Mumbai Indians  \
# 32                               1                        0
# 33                               1                        0
# 34                               1                        0
# ...

# %%
# feaure selection
from sklearn.ensemble import ExtraTreesRegressor 
model =ExtraTreesRegressor()
model.fit(real_x,real_y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.49308204e-02 1.96446765e-01 2.00023078e-01 4.77774621e-02
#  1.94487712e-01 1.89894953e-02 1.05133237e-02 1.11279449e-02
#  1.04421966e-02 1.18368924e-02 1.22275440e-02 1.18062929e-02
#  7.11337649e-03 1.15758684e-02 1.12634475e-02 1.20580854e-02
#  1.32289103e-02 1.35293842e-02 1.10916514e-02 8.61922113e-03
#  4.13736803e-03 4.95648199e-04 2.30319346e-04 3.82206651e-03
#  1.85352924e-03 3.53449496e-03 8.72137647e-03 1.18496171e-02
#  3.02199367e-03 1.04045598e-03 6.00458229e-03 6.18842405e-03
#  1.33915813e-02 9.91890106e-03 1.55051512e-03 1.96286808e-03
#  7.03132077e-04 4.45264673e-04 6.26511033e-03 9.90624458e-03
#  9.11072546e-03 3.48763153e-03 7.18614999e-03 1.95664198e-03
#  1.57458163e-03 4.64006301e-03 1.61097413e-03 9.26429195e-05
#  3.05493249e-03 1.31526913e-02]

# %%
fear_importances =pd.Series(model.feature_importances_,index =real_x.columns)
fear_importances.nlargest(50).plot(kind="barh")
plt.show()

# %%
data.corr()
# Out:
#                                                         runs   wickets  \
# runs                                                1.000000  0.358772
# wickets                                             0.358772  1.000000
# overs                                               0.879461  0.635545
# runs_last_5                                         0.584537 -0.203503
# wickets_last_5                                      0.115145  0.633080
# bat_team_Delhi Daredevils                          -0.029573  0.085299
# bat_team_Kings XI Punjab                            0.019176  0.042424
# bat_team_Kolkata Knight Riders                     -0.014833  0.005100
# bat_team_Mumbai Indians                            -0.006244 -0.014319
# bat_team_Rajasthan Royals                           0.009832 -0.029976
# bat_team_Royal Challengers Bangalore               -0.025356  0.008111
# bat_team_Sunrisers Hyderabad                        0.012850 -0.032061
# ...

# %%
# model selection

# %% [markdown]
# # Linear regressor

# %%
from sklearn.linear_model import LinearRegression
L_R =LinearRegression()
L_R.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
L_R.score(train_x,train_y)
# Out:
# 0.6680653835998507

# %%
L_R.score(test_x,test_y)
# Out:
# 0.7390062836101664

# %%
pred_y1 =L_R.predict(train_x)
pred_y2 =L_R.predict(test_x)

# %%
sns.distplot(train_y - pred_y1)

# %%
plt.scatter(train_y,pred_y1)

# %%
from sklearn import metrics
print("MAE:" ,metrics.mean_absolute_error(train_y,pred_y1))
print("MSE:" ,metrics.mean_squared_error(train_y,pred_y1))
print("RMAE:" ,np.sqrt(metrics.mean_squared_error(train_y,pred_y1)))
# Out:
# MAE: 12.770760138270372
# MSE: 291.6662378201922
# RMAE: 17.078238721255545

# %% [markdown]
# # lasso regressor

# %%
from sklearn.linear_model import Lasso
lasso =Lasso()
lasso.fit(train_x,train_y)
# Out:
# Lasso()

# %%
from sklearn.model_selection import GridSearchCV
parameters ={"alpha":[1e-15,1e-10,1e-8,1e-2,1,5,10,20,30,35,40]}
lasso =GridSearchCV(lasso,parameters,scoring ="neg_mean_squared_error",cv =5)
lasso.fit(real_x,real_y)
# Out:
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4585611.778395289, tolerance: 2740.7274487714367
#   positive)
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4374038.798063126, tolerance: 2768.3062010258845
#   positive)
# c:\users\dellx\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4668959.416122762, tolerance: 2963.8421624695975
#   positive)
# ...

# %%
print(lasso.best_params_)
print(lasso.best_score_)
# Out:
# {'alpha': 1}
# -316.6956427382021

# %%
lasso =Lasso(alpha=1)
lasso.fit(train_x,train_y)
# Out:
# Lasso(alpha=1)

# %%
lasso.score(train_x,train_y)
# Out:
# 0.6391116297832022

# %%
lasso.score(test_x,test_y)
# Out:
# 0.7415372132873657

# %% [markdown]
# # rendomforest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor =RandomForestRegressor()
regressor.fit(train_x,train_y)
# Out:
# RandomForestRegressor()

# %%
print(regressor.score(test_x,test_y))
print(regressor.score(train_x,train_y))
# Out:
# 0.6744947065334601
# 0.9976370170607102

# %%
#model evolution

# %%
pred_y3 =regressor.predict(test_x)
pred_y4 =regressor.predict(train_x)

# %%
sns.distplot(train_y-pred_y4)

# %%
sns.distplot(test_y -pred_y3)

# %%
plt.scatter(train_y,pred_y4)

# %%
plt.scatter(test_y,pred_y3)

# %%
#hyperparameter Tuning

# %%
rf =RandomForestRegressor()
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator =rf,param_distributions =random_grid,scoring ='neg_mean_squared_error',n_iter =100,cv =5,verbose =2,random_state =42)

# %%
rf_random.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.7s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.9s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.1s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
print(regressor.score(test_x,test_y))
print(regressor.score(train_x,train_y))
# Out:
# 0.6839586678152072
# 0.997601661993745

# %%
print(rf_random.best_params_)
print(rf_random.best_score_)
# Out:
# {'n_estimators': 1200, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'auto', 'max_depth': 10}
# -375.0760395359077

# %%
pred_y3 =regressor.predict(test_x)
pred_y4 =regressor.predict(train_x)

# %%
sns.distplot(train_y-pred_y4)

# %%
sns.distplot(test_y -pred_y3)

# %%
plt.scatter(train_y,pred_y4)

# %%
plt.scatter(test_y,pred_y3)
